# %% [markdown]
# <a href="https://colab.research.google.com/github/scj02/GemeloDigital/blob/Rama_Cris/Prueba_GUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
    <style>
        body {
            background: radial-gradient(circle, #1e1e1e, #000);
            color: white;
            font-family: Arial, sans-serif;
            text-align: center;
        }
        .avatar-container {
            margin-top: 50px;
        }
        .avatar {
            width: 200px;
            height: 200px;
            border-radius: 50%;
            background: linear-gradient(145deg, #3a3a3a, #1a1a1a);
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 80px;
        }
        .status {
            margin-top: 20px;
            font-size: 18px;
            opacity: 0.8;
        }
        .card {
            background: rgba(255,255,255,0.05);
            padding: 20px;
            border-radius: 12px;
            width: 300px;
            margin: auto;
        }
    </style>
</head>
<body>

<div class="avatar-container">
    <div class="card">
        <div class="avatar">🧑‍💻</div>
        <h2>Gemelo Digital</h2>
        <div class="status" id="status">Estado: Inicializando...</div>
    </div>
</div>

<script>
    const estados = [
        "Estudiando Estructuras de Datos",
        "Simulando carga académica",
        "Analizando Blockchain Privada",
        "Validando Gemelo Digital"
    ];

    let i = 0;
    setInterval(() => {
        document.getElementById("status").innerText =
            "Estado: " + estados[i % estados.length];
        i++;
    }, 2500);
</script>

</body>
</html>
"""

HTML(html_code)
